# %% [markdown]
# # Numerical Fact Checking System. Univeristy of Sheffield
#
# Pre-requisites:
#  * Gradle
#  * Java jdk8
#  * Python 3
#   * numpy
#   * jnius
#   * fuzzywuzzy
#   * sklearn
#   * urllib3

# %% [markdown]
# ## Configuration
# This defines the colleciton of tables that is used to populate the knowledge base

# %%
world = "herox"

# %% [markdown]
# ## Common setup
#
# Import required dependencies and download/install Stanford CoreNLP

# %%
import sys
import os
import re

#Set path manually to incldue sources location
if 'src/' not in sys.path:
    sys.path.append('src/')

# %% [markdown]
# If the following step fails. Run `gradlew writeClasspath` on the terminal in this folder. Then try again

# %%
#Load Java classpath for stanford corenlp using gradle. this will also install it if missing
from subprocess import run,PIPE
if 'CLASSPATH' not in os.environ:
    if not (os.path.exists('build') and os.path.exists('build/classpath.txt')):
        print("Generating classpath")
        r=run(["./gradlew", "writeClasspath"],stdout=PIPE, stderr=PIPE, universal_newlines=True)
        print(r.stdout)
        print(r.stderr)
              
    print("Loading classpath")
    os.environ['CLASSPATH'] = open('build/classpath.txt','r').read()
    print("Done")
# Out:
# Loading classpath
# Done

# %% [markdown]
# ### Feature Generation
#
# For each of the downloaded web pages. Parse the page and identify matches between the values in our tables and the data given in the web page. This only needs to be run once and will rememeber if it has been run before

# %%
from run.ds_generate_positive_features_for_query import precompute_features
precompute_features(world)
# Out:
# herox/1.csv	430,514,418.88	”Exxon Mobil" Market Value
#
# Done 1 out of 16
# Search for ”Exxon Mobil" Market Value
# Query already executed
# Missing file. Remove from dictionary and search again
# Search for ”Exxon Mobil" Market Value
# New Query
# Done URL 1 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://www.forbes.com/companies/exxon-mobil/
# https://www.forbes.com/companies/exxon-mobil/
# No meaningful text in this document
# Done URL 2 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://www.statista.com/statistics/264121/market-value-of-the-corporation-exxon-mobil-since-2001/
# https://www.statista.com/statistics/264121/market-value-of-the-corporation-exxon-mobil-since-2001/
# No meaningful text in this document
# Done URL 3 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://en.wikipedia.org/wiki/ExxonMobil
# https://en.wikipedia.org/wiki/ExxonMobil
# 199 candidate matches
# ["It is the largest direct descendant of John D. Rockefeller 's Standard Oil Company , and was formed on November 30 , 1999 by the merger of Exxon -LRB- formerly the Standard Oil Company of New Jersey -RRB- and Mobil -LRB- formerly the Standard Oil Company of New York -RRB- .", "The world 's 10th largest company by revenue , ExxonMobil from 1996 to 2017 , varied from the first to sixth largest publicly traded company by market capitalization .", 'The company was ranked ninth globally in the Forbes Global 2000 list in 2016 .', 'ExxonMobil was the second most profitable company in the Fortune 500 in 2014 .', "ExxonMobil is the largest of the world 's Big Oil companies , or supermajors , with daily production of 3.921 million BOE -LRB- barrels of oil equivalent -RRB- ; but significantly smaller than a number of national companies .", 'In 2008 , this was approximately 3 percent of world production , which is less than several of the largest state-owned petroleum companies .', 'When ranked by oil and gas reserves , it is 14th in the world -- with less than 1 percent of the total .', "ExxonMobil 's reserves were 20 billion BOE at the end of 2016 and the 2007 rates of production were expected to last more than 14 years .", 'With 37 oil refineries in 21 countries constituting a combined daily refining capacity of 6.3 million barrels -LRB- 1,000,000 m3 -RRB- , ExxonMobil is the largest refiner in the world , a title that was also associated with Standard Oil since its incorporation in 1870 .', "ExxonMobil has been criticized for its slow response to cleanup efforts after the 1989 Exxon Valdez oil spill in Alaska , widely considered to be one of the world 's worst oil spills in terms of damage to the environment .", 'ExxonMobil was formed in 1999 by the merger of two major oil companies , Exxon and Mobil .', 'Both Exxon and Mobil were descendants of Standard Oil , established by John D. Rockefeller and partners in 1870 as the Standard Oil Company of Ohio .', 'In 1882 , it together with its affiliated companies was incorporated as the Standard Oil Trust with Standard Oil Company of New Jersey and Standard Oil Company of New York as its largest companies .', 'The Anglo-American Oil Company was established in the United Kingdom in 1888 .', 'In 1890 , Standard Oil , together with local ship merchants in Bremen established Deutsch-Amerikanische Petroleum Gesellschaft -LRB- later : Esso A.G. -RRB- .', 'In 1891 , a sale branch for the Netherlands and Belgium , American Petroleum Company , was established in Rotterdam .', 'The Standard Oil Trust was dissolved under the Sherman Antitrust Act in 1892 ; however , it reemerged as the Standard Oil Interests .', 'In 1893 , the Chinese and the whole Asian kerosene market was assigned to Standard Oil Company of New York in order to improve trade with the Asian counterparts .', 'In 1898 , Standard Oil of New Jersey acquired controlling stake in Imperial Oil of Canada .', 'In 1899 , Standard Oil Company of New Jersey became the holding company for the Standard Oil Interests .', 'The anti-monopoly proceedings against the Standard Oil were launched in 1898 .', "The reputation of Standard Oil in the public eye suffered badly after publication of Ida M. Tarbell 's classic exposé The History of the Standard Oil Co. in 1904 , leading to a growing outcry for the government to take action against the company .", 'By 1911 , with public outcry at a climax , the Supreme Court of the United States ruled that Standard Oil must be dissolved and split into 34 companies .', "Two of these companies were Jersey Standard -LRB- `` Standard Oil Co. of New Jersey '' -RRB- , which eventually became Exxon , and Socony -LRB- `` Standard Oil Co. of New York '' -RRB- , which eventually became Mobil .", 'John Duston Archbold was the first president of Jersey Standard .', 'Archbold was followed by Walter C. Teagle in 1917 , who made it the largest oil company in the world .', 'In 1919 , Jersey Standard acquired a 50 % share in Humbl ...
# About to parse
# Annotated
# Target 430514418.88		Actual 5		Class		0
# Target 430514418.88		Actual 10		Class		0
# Target 430514418.88		Actual 2		Class		0
# Target 430514418.88		Actual 10		Class		0
# Target 430514418.88		Actual 2013		Class		0
# Target 430514418.88		Actual 5070000.0		Class		0
# Target 430514418.88		Actual 5070000.0		Class		0
# Target 430514418.88		Actual 4190000.0000000005		Class		0
# Target 430514418.88		Actual 4190000.0000000005		Class		0
# Target 430514418.88		Actual 2015		Class		0
# Target 430514418.88		Actual 10		Class		0
# Target 430514418.88		Actual 2011		Class		0
# Target 430514418.88		Actual 1		Class		0
# Target 430514418.88		Actual 2011		Class		0
# Target 430514418.88		Actual 11		Class		0
# Target 430514418.88		Actual 2017		Class		0
# Target 430514418.88		Actual 11		Class		0
# Target 430514418.88		Actual 2017		Class		0
# Target 430514418.88		Actual 1973		Class		0
# Target 430514418.88		Actual 1973		Class		0
# Target 430514418.88		Actual 40610000000.0		Class		0
# Target 430514418.88		Actual 40610000000.0		Class		0
# Target 430514418.88		Actual 11000000.0		Class		0
# Target 430514418.88		Actual 42000		Class		0
# Target 430514418.88		Actual 24		Class		0
# Target 430514418.88		Actual 1989		Class		0
# Target 430514418.88		Actual 2012		Class		0
# Target 430514418.88		Actual 2014		Class		0
# [{'class': 0, 'header_match_intersection': 0, 'complete_bow': ['occupied'], 'dep_path_bow': [], 'type': 'number', 'value': 5, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['occupied', 'five', 'out', 'of'], 'dep_path_bow': [], 'type': 'number', 'value': 10, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['occupied', 'five', 'out', 'of', 'ten', 'slots', 'for', 'Largest', 'Corporate', 'Annual', 'Earnings', 'of', 'All', 'Time', 'and'], 'dep_path_bow': [], 'type': 'number', 'value': 2, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['occupied', 'five', 'out', 'of', 'ten', 'slots', 'for', 'Largest', 'Corporate', 'Annual', 'Earnings', 'of', 'All', 'Time', 'and', 'two', 'out', 'of'], 'dep_path_bow': [], 'type': 'number', 'value': 10, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [','], 'dep_path_bow': [], 'type': 'date', 'value': 2013, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['settled', 'charges', 'that', 'it', 'violated', 'the', 'federal', 'Clean', 'Water', 'Act', 'and', 'state', 'environmental', 'laws', ',', 'for', '$'], 'dep_path_bow': [], 'type': 'number', 'value': 5070000.0, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['settled', 'charges', 'that', 'it', 'violated', 'the', 'federal', 'Clean', 'Water', 'Act', 'and', 'state', 'environmental', 'laws', ',', 'for', '$'], 'dep_path_bow': [], 'type': 'number', 'value': 5070000.0, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['settled', 'charges', 'that', 'it', 'violated', 'the', 'federal', 'Clean', 'Water', 'Act', 'and', 'state', 'environmental', 'laws', ',', 'for', '$', '5.07', 'million', ',', 'including', '$'], 'dep_path_bow': [], 'type': 'number', 'value': 4190000.0000000005, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['settled', 'charges', 'that', 'it', 'violated', 'the', 'federal', 'Clean', 'Water', 'Act', 'and', 'state', 'environmental', 'laws', ',', 'for', '$', '5.07', 'million', ',', 'including', '$'], 'dep_path_bow': [], 'type': 'number', 'value': 4190000.0000000005, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [','], 'dep_path_bow': ['2015'], 'type': 'date', 'value': 2015, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['pipeline', 'running', 'from', 'Silver', 'Tip', 'to', 'Billings', ',', 'Montana', ',', 'which', 'ruptured', 'about'], 'dep_path_bow': [], 'type': 'number', 'value': 10, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['Yellowstone', 'River', 'oil', 'spill', 'was', 'an', 'oil', 'spill', 'from', 'an'], 'dep_path_bow': ['spill'], 'type': 'date', 'value': 2011, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['pipeline', 'running', 'from', 'Silver', 'Tip', 'to', 'Billings', ',', 'Montana', ',', 'which', 'ruptured', 'about', '10', 'miles', 'west', 'of', 'Billings', 'on', 'July'], 'dep_path_bow': [], 'type': 'date', 'value': 1, 'entity': 'Exxon Mobil', 'entity_utterance': 'ExxonMobil'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['pipeline', 'running', 'from', 'Silver', 'Tip', 'to', 'Billings', ',', 'Montana', ',', 'which', 'ruptured', 'about', '10', 'miles', 'west', 'of', 'Billings', 'on', 'July', '1', ','], 'dep_path_bow': [], 'type': 'date', 'value': 2011,  ...
# Done URL 4 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://ycharts.com/companies/XOM/market_cap
# https://ycharts.com/companies/XOM/market_cap
# No meaningful text in this document
# Done URL 5 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://en.wikipedia.org/wiki/List_of_public_corporations_by_market_capitalization
# https://en.wikipedia.org/wiki/List_of_public_corporations_by_market_capitalization
# 29 candidate matches
# ['This list is based on the Financial Times Global 500 rankings .', 'Only companies with free float at least 15 % are included , value of unlisted stock classes is excluded .', 'This list is up to date as of March 31 , 2018 -LSB- update -RSB- .', 'This list is up to date as of December 31 , 2017 -LSB- update -RSB- .', 'This list is up to date as of December 31 , 2016 -LSB- update -RSB- .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2015 -LSB- update -RSB- .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2014 -LSB- update -RSB- .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2013 .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2012 .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2011 .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2010 .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2009 .', 'This Financial Times Global 500 -- based list is up to date as of December 31 , 2008 .', 'This Financial Times -- based list is up to date as of December 31 , 2007 .', 'Fourth quarter This Financial Times -- based list is up to date as of December 2006 .', 'Third quarter This Financial Times -- based list is up to date as of 30 September 2006 .', 'Second quarter This Financial Times -- based list is up to date as of 30 June 2006 .', 'First quarter This Financial Times -- based list is up to date as of March 2006 .', 'This Financial Times -- based list is up to date as of 31 March 2005 .', 'This Financial Times -- based list is up to date as of 31 March 2004 .', 'This Financial Times -- based list is up to date as of 31 March 2003 .', 'This Financial Times -- based list is up to date as of 31 March 2002 .', 'This Financial Times -- based list is up to date as of 31 March 2001 .', 'This Financial Times -- based list is up to date as of 31 March 2000 .', 'This Financial Times -- based list is up to date as of 30 September 1998 .', 'This Financial Times -- based list is up to date as of 30 September 1997 .', 'This Financial Times -- based list is up to date as of 30 September 1996 .', 'This Financial Times Non-Public 150 based list is up to date as of December , 2006 .', 'All companies in top 10 are government-owned corporations .']
# About to parse
# Annotated
# []
# Done URL 6 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://quotes.wsj.com/XOM
# https://quotes.wsj.com/XOM
# 2 candidate matches
# ['Quote data , except U.S. stocks , provided by SIX Financial Information .', 'SIX Financial Information -LRB- a -RRB- does not make any express or implied warranties of any kind regarding the data , including , without limitation , any warranty of merchantability or fitness for a particular purpose or use ; and -LRB- b -RRB- shall not be liable for any errors , incompleteness , interruption or delay , action taken in reliance on any data , or for any damages resulting therefrom .']
# About to parse
# Annotated
# []
# Done URL 7 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://www.stock-analysis-on.net/NYSE/Company/Exxon-Mobil-Corp/Performance-Measure/Market-Value-Added
# https://www.stock-analysis-on.net/NYSE/Company/Exxon-Mobil-Corp/Performance-Measure/Market-Value-Added
# No meaningful text in this document
# Done URL 8 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://finance.yahoo.com/quote/XOM/key-statistics
# https://finance.yahoo.com/quote/XOM/key-statistics
# No meaningful text in this document
# Done URL 9 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://www.nasdaq.com/symbol/xom
# https://www.nasdaq.com/symbol/xom
# No meaningful text in this document
# Done URL 10 out of 10
#
# Looking in document for values similar to 430,514,418.88
# https://www.statista.com/topics/1109/exxonmobil/
# https://www.statista.com/topics/1109/exxonmobil/
# No meaningful text in this document
# herox/2.csv	90,000	"Unaccompanied children" claimed asylum
#
# Done 2 out of 16
# Search for "Unaccompanied children" claimed asylum
# Query already executed
# Missing file. Remove from dictionary and search again
# Search for "Unaccompanied children" claimed asylum
# New Query
# Done URL 1 out of 10
#
# Looking in document for values similar to 90,000
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/656425/UASC_Safeguarding_Strategy_2017.pdf
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/656425/UASC_Safeguarding_Strategy_2017.pdf
# No meaningful text in this document
# Done URL 2 out of 10
#
# Looking in document for values similar to 90,000
# http://www.coram.org.uk/how-we-do-it/upholding-childrens-rights/migrant-childrens-project
# http://www.coram.org.uk/how-we-do-it/upholding-childrens-rights/migrant-childrens-project
# 4 candidate matches
# ['In the past year in England , more than 4,000 unaccompanied children claimed asylum compared with 2,569 the year before .', 'The current European migrant crisis , in which 25 % of migrants are estimated to be children , has meant that MCP is more vital than ever .', 'Before the Act was passed , CCLC won some important concessions including a change meaning that those with a pending application to the Home Office when they turn 18 will still receive leaving-care support .', '* Rise in lone children claiming asylum in England , BBC website , 7 September 2016 , http://www.bbc.co.uk/news/uk-england-36714617']
# About to parse
# Annotated
# Target 90000		Actual 25		Class		0
# Target 90000		Actual 7		Class		0
# Target 90000		Actual 2016		Class		0
# Target 90000		Actual 4000		Class		0
# Target 90000		Actual 2569		Class		0
# [{'class': 0, 'header_match_intersection': 0, 'complete_bow': ['%', 'of', 'migrants', 'are', 'estimated', 'to', 'be'], 'dep_path_bow': [], 'type': 'number', 'value': 25, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['claiming', 'asylum', 'in', 'England', ',', 'BBC', 'website', ','], 'dep_path_bow': [], 'type': 'date', 'value': 7, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['claiming', 'asylum', 'in', 'England', ',', 'BBC', 'website', ',', '7', 'September'], 'dep_path_bow': [], 'type': 'date', 'value': 2016, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 1, 'complete_bow': [], 'dep_path_bow': [], 'type': 'number', 'value': 4000, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied children'}, {'class': 0, 'header_match_intersection': 1, 'complete_bow': ['claimed', 'asylum', 'compared', 'with'], 'dep_path_bow': [], 'type': 'number', 'value': 2569, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied children'}]
# Done URL 3 out of 10
#
# Looking in document for values similar to 90,000
# https://www.thebureauinvestigates.com/stories/2016-04-10/revealed-fourfold-rise-as-95-000-unaccompanied-children-claim-asylum-in-europe-in-2015
# https://www.thebureauinvestigates.com/stories/2016-04-10/revealed-fourfold-rise-as-95-000-unaccompanied-children-claim-asylum-in-europe-in-2015
# 31 candidate matches
# ['Record numbers of children are seeking refuge in Europe -LRB- Unicef/Klincarov -RRB- At least 95,000 unaccompanied children applied for asylum in Europe last year , four times the numbers for 2014 , Bureau research can reveal .', 'From approaching 29 different governments for statistics , we found at least 95,070 applied for asylum in Europe in 2015 , up from 23,572 in 2014 .', "It is the first time any concrete figure has been reported for the actual scale of migration among unaccompanied minors during last year 's refugee crisis An estimate was given by Save the Children in January when the charity suggested 26,000 unaccompanied children arrived in Europe in 2015 .", 'Only 17 of the 29 countries we approached provided any data .', 'The Bureau has been investigating the issues faced by unaccompanied minors for two years .', 'We approached 27 EU member states for numbers , plus Norway and Switzerland .', 'Almost all the larger countries were among the 17 which provided details .', 'Of those 17 , Sweden registered the most asylum applications by lone children in 2015 -- 35,369 .', 'This was followed by 14,439 in Germany , 9,331 in Austria and 8,804 in Hungary .', 'The UK came in ninth place with 3,043 .', 'In Sweden , the rise was 402 % .', 'In Hungary , which is considered a transit country where many asylum claims are first made , applications soared from 607 to 8,804 .', 'She said in the first 11 weeks of 2016 , 1,156 unaccompanied and separated children had been registered there .', "`` Children first and foremost are children -- they do n't know if they are refugees or migrants -- they just know they are children and should be treated and welcomed as that . ''", "Hamid , 12 -- Photo : Maeve McClenaghan When the Bureau met Hamid at a children 's reception centre in Malmo , Sweden , late last year , he was like any other excitable , football-loving 12-year-old boy .", 'He lives in hope he will one day soon meet his mum again .', 'An Afghan , he was travelling to Europe with his mother and four siblings when shooting broke out at the border of Turkey and Iran .', 'There Hamid was put in a transit centre , a place intended to house children for just two or three days .', 'Hamid has now been in Sweden for more than four months -- and still no sign of hope .', 'Our research found that the largest number of unaccompanied minors were from Afghanistan , with 23,480 claiming asylum in Sweden alone in 2015 .', 'Sweden also saw 3,777 Syrian youngsters register claims .', 'In the UK , the numbers were much smaller with 694 minors from Eritrea topping the list .', 'Only 186 came from Syria .', 'It made 4,660 decisions on unaccompanied minors last year , with 3,076 receiving a usually permanent residence permit -- a success rate of 66 % .', 'In the UK , the asylum success rate was 23 % .', 'Only the UK and Sweden could provide data on how many former asylum-seeking children had been returned once they turned 18 .', 'In the past seven years , Sweden has returned at least 224 children , while over nine years the UK has returned 2,675 to Afghanistan and Iraq alone .', 'This expires when they reach 18 and they must then apply for permanent asylum or temporary leave to remain .', 'But one of the biggest differences among the countries analysed was in how states assess the true age of those arriving .', 'Because most countries provide higher standards of care for children , there is a degree of suspicion among immigration officials that some claiming to be minors are in fact over the age of 18 .', 'A study in Denmark of its 2014 intake of asylum seeing children found that in 72 % of the 282 questionable cases , those claiming to be minors were adults .']
# About to parse
# Annotated
# Target 90000		Actual 2		Class		0
# Target 90000		Actual 72		Class		0
# Target 90000		Actual 282		Class		0
# Target 90000		Actual 2014		Class		0
# Target 90000		Actual 26000		Class		0
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 26000		Class		0
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 26000		Class		0
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 17		Class		0
# Target 90000		Actual 35369		Class		0
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 18		Class		0
# Target 90000		Actual 1156		Class		0
# Target 90000		Actual 11		Class		0
# Target 90000		Actual 11		Class		0
# Target 90000		Actual 2016		Class		0
# Target 90000		Actual 1156		Class		0
# Target 90000		Actual 11		Class		0
# Target 90000		Actual 11		Class		0
# Target 90000		Actual 2016		Class		0
# Target 90000		Actual 95000		Class		1
# Target 90000		Actual 4		Class		0
# Target 90000		Actual 2014		Class		0
# Target 90000		Actual 95000		Class		1
# Target 90000		Actual 4		Class		0
# Target 90000		Actual 2014		Class		0
# Target 90000		Actual 12		Class		0
# Target 90000		Actual 18		Class		0
# Target 90000		Actual 224		Class		0
# Target 90000		Actual 2675		Class		0
# [{'class': 0, 'header_match_intersection': 0, 'complete_bow': ['for', 'just'], 'dep_path_bow': [], 'type': 'number', 'value': 2, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['found', 'that', 'in'], 'dep_path_bow': [], 'type': 'number', 'value': 72, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['found', 'that', 'in', '72', '%', 'of', 'the'], 'dep_path_bow': [], 'type': 'number', 'value': 282, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['intake', 'of', 'asylum', 'seeing'], 'dep_path_bow': [], 'type': 'date', 'value': 2014, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['minors', 'during', 'last', 'year', "'s", 'refugee', 'crisis', 'An', 'estimate', 'was', 'given', 'by', 'Save', 'the', 'Children', 'in', 'January', 'when', 'the', 'charity', 'suggested'], 'dep_path_bow': [], 'type': 'number', 'value': 26000, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['minors', 'during', 'last', 'year', "'s", 'refugee', 'crisis', 'An', 'estimate', 'was', 'given', 'by', 'Save', 'the', 'Children', 'in', 'January', 'when', 'the', 'charity', 'suggested', '26,000', 'unaccompanied', 'children', 'arrived', 'in', 'Europe', 'in'], 'dep_path_bow': [], 'type': 'date', 'value': 2015, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['in', 'January', 'when', 'the', 'charity', 'suggested'], 'dep_path_bow': [], 'type': 'number', 'value': 26000, 'entity': 'Unaccompanied children', 'entity_utterance': 'Children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['in', 'January', 'when', 'the', 'charity', 'suggested', '26,000', 'unaccompanied', 'children', 'arrived', 'in', 'Europe', 'in'], 'dep_path_bow': [], 'type': 'date', 'value': 2015, 'entity': 'Unaccompanied children', 'entity_utterance': 'Children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [], 'dep_path_bow': [], 'type': 'number', 'value': 26000, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['arrived', 'in', 'Europe', 'in'], 'dep_path_bow': [], 'type': 'date', 'value': 2015, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [',', 'Sweden', 'registered', 'the', 'most', 'asylum', 'applications', 'by', 'lone'], 'dep_path_bow': [], 'type': 'number', 'value': 17, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['in', '2015', '--'], 'dep_path_bow': [], 'type': 'number', 'value': 35369, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['in'], 'dep_path_bow': [], 'type': 'date', 'value': 2015, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [',', 'there', 'is', 'a', 'degree', 'of', 'suspicion', 'among', 'immigration', 'officials', 'that', 'some', 'claiming', 'to', 'be', 'minors', 'are', 'in', 'fact', 'over', 'the', 'age', 'of'], 'dep_path_bow': [], 'type': 'number', 'value': 18, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [], 'dep_path_bow': [], 'type': 'number', 'value': 1156, 'entity': 'Unaccompanied children', 'entity_utterance': 'unaccompanied'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['weeks', 'of', '2016', ',', '1,156'], 'dep_path_b ...
# Done URL 4 out of 10
#
# Looking in document for values similar to 90,000
# https://www.refugeecouncil.org.uk/what_we_do/childrens_services
# https://www.refugeecouncil.org.uk/what_we_do/childrens_services
# 1 candidate matches
# ["In 2017 , over 2500 separated children were referred to the Refugee Council 's Children 's Section ."]
# About to parse
# Annotated
# Target 90000		Actual 2500		Class		0
# Target 90000		Actual 2017		Class		0
# Target 90000		Actual 2500		Class		0
# Target 90000		Actual 2017		Class		0
# [{'class': 0, 'header_match_intersection': 0, 'complete_bow': ['separated'], 'dep_path_bow': [], 'type': 'number', 'value': 2500, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [',', 'over', '2500', 'separated'], 'dep_path_bow': ['2017'], 'type': 'date', 'value': 2017, 'entity': 'Unaccompanied children', 'entity_utterance': 'children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': ['separated', 'children', 'were', 'referred', 'to', 'the', 'Refugee', 'Council', "'s"], 'dep_path_bow': [], 'type': 'number', 'value': 2500, 'entity': 'Unaccompanied children', 'entity_utterance': 'Children'}, {'class': 0, 'header_match_intersection': 0, 'complete_bow': [',', 'over', '2500', 'separated', 'children', 'were', 'referred', 'to', 'the', 'Refugee', 'Council', "'s"], 'dep_path_bow': ['referred'], 'type': 'date', 'value': 2017, 'entity': 'Unaccompanied children', 'entity_utterance': 'Children'}]
# Done URL 5 out of 10
#
# Looking in document for values similar to 90,000
# https://fullfact.org/immigration/unaccompanied-refugee-children-europe/
# https://fullfact.org/immigration/unaccompanied-refugee-children-europe/
# 19 candidate matches
# ['`` -LSB- we were originally calling for the government to resettle -RSB- 3,000 children out of what we then thought were 26,000 child refugees in Europe .', "We now learn that the figure is much higher and 95,000 has been quoted . ''", "Nearly 90,000 unaccompanied children sought asylum in Europe in 2015 `` It is not possible to say with certainty how many unaccompanied migrant children are in the EU as a whole , including the UK . ''", "The European Commission found that , in 2013 , as many unaccompanied children applied for asylum in the EU as did n't .", 'Around 90,000 applications from unaccompanied children to European countries This is the number of asylum applications made by unaccompanied children in Europe in 2015 .', "It 's about 88,000 if you just count EU member countries and about 96,000 if you include a few other western European countries also covered by the statistics .", 'Previous to this , something like 13,000 applications were made each year .', "About 3,300 of last year 's applications were for asylum in the UK .", 'The vast majority -- over 90 % - are from boys .', 'Last year just over 1,200 children were granted this in the UK , while 850 have been accepted in the first six months of 2016 .', "MPs clashed earlier this year over whether the UK should commit to accepting 3,000 `` unaccompanied refugee children '' .", 'At the time , the charity estimated that figure at around 26,000 .', 'It now seems to recognise the figures showing upwards of 90,000 children across Europe .', 'In the end , parliament voted against a commitment to resettling 3,000 , although the government has since said it will resettle some children from Greece , Italy and France , consulting with local authorities on what the exact numbers should be .', '30 children have been resettled so far since these commitments were made in May this year .', 'The government also committed to resettling up to 3,000 children and adults from the Middle East and North Africa , and has previously said it will resettle some children as part of its Syrian resettlement programme .', "The charity Citizens UK was quoted last week claiming `` In the 1930s , 10,000 Jewish children crossed Europe and gained safety in the UK because families here raised the money to sponsor them . ''", 'We rely on your donations to continue and grow our factchecking efforts - to help us maintain our independence we need 1000 donors to give # 10 a month .', 'We are currently at 502 - please help Full Fact grow .']
# About to parse
# Annotated
# Target 90000		Actual 90000		Class		1
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 90000		Class		1
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 90000		Class		1
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 3000		Class		0
# Target 90000		Actual 90000		Class		1
# Target 90000		Actual 90000		Class		1
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 90000		Class		1
# Target 90000		Actual 2015		Class		0
# Target 90000		Actual 2013		Class		0
# Target 90000		Actual 10000		Class		0
# Target 90000		Actual 30		Class		0
# Target 90000		Actual 3000		Class		0
# Target 90000		Actual 26000		Class		0
# Target 90000		Actual 3000		Class		0
# Target 90000		Actual 3000		Class		0
# Target 90000		Actual 1200		Class		0
# Target 90000		Actual 850		Class		0
# Target 90000		Actual 6		Class		0
# Target 90000		Actual 6		Class		0
# Target 90000		Actual 2016		Class		0
# Target 90000		Actual 3000		Class		0
# Target 90000		Actual 3000		Class		0
# ...
# http://ec.europa.eu/eurostat/statistics-explained/index.php/Tobacco_consumption_statistics
# http://ec.europa.eu/eurostat/statistics-explained/index.php/Tobacco_consumption_statistics
# 29 candidate matches
# ['This article is one of a set of statistical articles concerning health determinants in the EU which forms part of an online publication on health statistics .', 'The data in this article are from the European health interview survey -LRB- EHIS -RRB- which was conducted between 2013 and 2015 and which covered persons aged 15 and over .', 'Men were more likely than women to be daily smokers Among the 27 EU Member States for which data are available , the proportion of daily smokers ranged from 8.7 % in Sweden to 27.0 nbsp ; % in Greece and 27.3 % in Bulgaria -LRB- see Table 1 -RRB- .', 'Among men , the proportion of daily smokers ranged from 7.5 % in Sweden to 37.3 % in Cyprus , while among women , the proportion ranged from 8.3 % in Romania to 22.0 % in Austria .', 'In 26 of these Member States the proportion of daily smokers was higher among men than among women , with Sweden as the only exception with close to 2 percentage points -LRB- pp -RRB- less of male smokers compared to female smokers .', 'The largest gender difference , in percentage point terms , was in Lithuania and Romania , where the proportion of daily smokers among men was around 24 pp points above the share recorded among women .', 'Gender differences in excess of 20 points were also observed in Cyprus and Latvia -LRB- see Figure 1 -RRB- .', 'The smallest gender differences were observed in Finland -LRB- 2 pp -RRB- , the United Kingdom and Denmark -LRB- 1 pp -RRB- .', 'The proportion of daily smokers generally decreased after the age group 45 -- 54 years In broad terms , at EU level , the age profile of daily smokers was similar for men and women : the proportion increased between the age groups 15 -- 24 and 25 -- 34 ; for the age groups from 25 -- 34 to 45 -- 54 the proportion of daily smokers remained generally high ; thereafter the shares fell , with by far the lowest proportion of daily smokers among the older age groups .', 'Most of the EU Member States followed this broad pattern , with the highest proportions reported between the ages of 25 and 54 and the lowest in the age groups over 65 -LRB- see Table 2 -RRB- .', 'More than 45 % of men were daily smokers in Bulgaria in the age groups between 35 and 54 and also in Cyprus in the age group 25 and 34 and Latvia in the age groups between 35 and 44 .', 'A notable example of the latter was Lithuania where the proportion of daily smokers in the age group over 75 was 35 times higher among men -LRB- 7 % -RRB- than among women -LRB- 0.2 % -RRB- .', 'On average , the smallest relative differences between men and women were observed in the youngest age group -LRB- 15 -- 24 -RRB- .', 'For a few age groups in a few of the participating EU Member States the prevalence of daily smoking among men and women was similar , or even higher among women , for example in Sweden , in the age groups over 35 , in Denmark -LRB- in the 15 -- 24 , 55-64 and 65-74 age groups -RRB- and in Austria in the age group 55 -- 64 .', 'The proportion of daily smokers of cigarettes was generally highest among people having completed upper secondary or post-secondary non-tertiary education , although there were quite different patterns for men and women From Figure 2 it can be seen that the prevalence of daily smoking was generally lowest among people having completed tertiary education and highest among those having completed upper secondary or post-secondary non-tertiary education .', 'A similar analysis is presented in Table 3 , but with separate data for men and women .', 'As such , in 19 EU Member States the highest share of daily smokers among women was recorded among those having completed upper secondary or post-secondary non-tertiary education .', 'Looking in more detail , relatively low proportions of daily smokers were reported in Cyprus , Romania and Lithuania for women having completed at most lower secondary education , at least 4 pp lower than for women in either of the other education categories shown in Table 3 .', 'Equally , a ...
# About to parse
# Annotated
# []
# Done URL 5 out of 10
#
# Looking in document for values similar to 15.1
# https://www.usatoday.com/
# https://www.usatoday.com/
# No meaningful text in this document
# Done URL 6 out of 10
#
# Looking in document for values similar to 15.1
# http://www.nydailynews.com/
# http://www.nydailynews.com/
# No meaningful text in this document
# Done URL 7 out of 10
#
# Looking in document for values similar to 15.1
# http://www.abs.gov.au/ausstats/abs@.nsf/Lookup/by%20Subject/4364.0.55.001~2014-15~Main%20Features~Smoking~24
# http://www.abs.gov.au/ausstats/abs@.nsf/Lookup/by%20Subject/4364.0.55.001~2014-15~Main%20Features~Smoking~24
# 28 candidate matches
# ['Tobacco smoking is one of the largest preventable causes of death and disease in Australia .', 'Tobacco was responsible for 7.8 % of the total burden of disease and injury in Australia in 2003 , equivalent to around 15,000 deaths per year , and was estimated to cost Australia $ 31.5 billion in social -LRB- including health -RRB- and economic costs in 2004-05 .', 'In 2014-15 , 14.5 % of adults aged 18 years and over were daily smokers -LRB- 2.6 million adults -RRB- , down from 16.1 % in 2011-12 .', 'This decrease is a continuation of the trend over the past two decades .', 'In 2001 , 22.4 % of adults smoked daily while 23.8 % of adults smoked daily in 1995 .', 'In 2014-15 , 16.9 % of males and 12.1 % of women smoked daily , with a similar but higher pattern in 1995 -LRB- 27.3 % of men compared with 20.3 % of women -RRB- .', 'Source -LRB- s -RRB- : National Health Survey : First Results , 2014-15 The following graph shows decreases in daily smoking rates across age and sex from 1995 to 2014-15 .', 'Source -LRB- s -RRB- : National Health Survey : First Results , 2014-15 In particular , rates of daily smoking have decreased considerably amongst younger adults since 2001 , while rates for older adults have also decreased but to a lesser extent .', 'In 2001 , 28.2 % of 18-44 year olds smoked daily , decreasing to 16.3 % in 2014-15 .', 'Of adults aged 45 years and over , 15.9 % smoked daily in 2001 , decreasing to 12.7 % in 2014-15 .', 'Source -LRB- s -RRB- : National Health Survey : First Results , 2014-15 A further 1.5 % of adults smoked less often than daily in 2014-15 , while nearly one third -LRB- 31.4 % -RRB- were ex-smokers and just over half -LRB- 52.6 % -RRB- had never smoked .', 'Similar to 2011-12 , the Northern Territory had the highest rate of daily smokers -LRB- 20.9 % -RRB- in 2014-15 , followed by Tasmania -LRB- 17.9 % -RRB- .', 'The Australian Capital Territory had the lowest rate of daily smokers in 2014-15 -LRB- 12.4 % -RRB- .', 'In 2014-15 , people living in Outer Regional and Remote areas of Australia had higher rates of daily smoking -LRB- 20.9 % -RRB- than people in Inner Regional areas -LRB- 16.7 % -RRB- or Major Cities -LRB- 13.0 % -RRB- .', 'While rates of daily smoking have decreased across all remoteness areas over the past 10-15 years , the rate for Outer Regional and Remote areas is only now similar to that of Major Cities a decade ago -LRB- 19.9 % in 2004-05 -RRB- .', 'Source -LRB- s -RRB- : National Health Survey : First Results , 2014-15 Rates of smoking are also considerably higher amongst people living in areas of Australia with the most disadvantage .', 'In 2014-15 , 21.4 % of people living in areas of most disadvantage -LRB- first quintile -RRB- smoked daily , compared with 8.0 % of people living in areas of the least disadvantage -LRB- fifth quintile -RRB- .', 'Footnote -LRB- s -RRB- : -LRB- a -RRB- Based on the 2011 Index of Relative Socio-Economic Disadvantage .', 'A lower Index of Disadvantage quintile -LRB- e.g. the first quintile -RRB- indicates an area with relatively greater disadvantage .', 'A higher Index of Disadvantage -LRB- e.g. the fifth quintile -RRB- indicates an area with a relative lack of disadvantage .', 'Source -LRB- s -RRB- : National Health Survey : First Results , 2014-15 In 2014-15 , 2.7 % of 15-17 year olds were daily smokers , similar to 2011-12 -LRB- 4.2 % -RRB- .', 'A further 0.5 % smoked less often than daily , 1.8 % were ex-smokers , and 94.2 % reported that they had never smoked .', "1 Department of Health , ` Tobacco control ' < http://www.health.gov.au/internet/main/publishing.nsf/content/tobacco > ; last accessed 03/12/2015 .", '2 Begg S , Vos T , Barker B , Stevenson C , Stanley L and Lopez AD 2007 .', 'The Burden of Disease and Injury in Australia 2003 , AIHW cat .', 'PHE 82 , Canberra : Australian Institute of Health and Welfare , < http://www.aihw.gov.au/publication-detail/?id=6442467990 > ; last accessed 03/12/2015 .', '3 Collins D & Lapsley H 2008 .', 'Th ...
# About to parse
# Annotated
# []
# Done URL 8 out of 10
#
# Looking in document for values similar to 15.1
# https://www.livescience.com/48923-usa-smoking-declines-to-lowest.html
# https://www.livescience.com/48923-usa-smoking-declines-to-lowest.html
# 13 candidate matches
# ['The percentage of U.S. adults who smoke cigarettes was 17.8 percent in 2013 , a drop from 20.9 percent in 2005 , and the lowest rate of smoking since researchers began tracking this figure in 1965 , according to the report from the U.S. Centers for Disease Control and Prevention -LRB- CDC -RRB- .', 'The report also found the number of cigarette smokers was 42.1 million in 2013 , a drop from 45.1 million in 2005 , even though the U.S. population is increasing .', '-LSB- 10 Scientific Quit-Smoking Tips -RSB- The decline in smoking rates varied among different populations and regions .', 'For the first time , the researchers had data to break out the smoking rate of people who are lesbian , gay or bisexual .', 'The smoking rate in this group was 26.6 percent , higher than the smoking rate among straight people , which was 17.6 percent .', 'Among U.S. regions , people in the Midwest had the highest smoking rate , of 20.5 percent .', 'The smoking rate was 19.2 percent among people in the South , and 16.9 among people in the Northeast .', 'People who live in the West had the lowest smoking rate , of 13.6 percent , according to the report .', 'Cigarette smoking is considered the leading preventable cause of disease and death in the United States , killing more than 480,000 Americans each year , according to the CDC .', "Smoking leads to cancer , and is also a factor in heart and metabolic diseases , which account for 40 percent of tobacco-related deaths , according to the U.S. Surgeon General 's report in 2014 .", 'Among current cigarette smokers , the proportion of those who smoke every day was 76.9 percent in 2013 , decreasing from 80.8 percent in 2005 .', 'People who smoked daily reported smoking on average 14.2 cigarettes per day in 2013 , compared with 16.7 cigarettes in 2005 .', "`` Smokers who quit before they 're 40 years old can get back almost all of the 10 years of life expectancy smoking takes away . ''"]
# About to parse
# Annotated
# []
# Done URL 9 out of 10
#
# Looking in document for values similar to 15.1
# https://www.cdc.gov/mmwr/preview/mmwrhtml/mm6347a4.htm
# https://www.cdc.gov/mmwr/preview/mmwrhtml/mm6347a4.htm
# 10 candidate matches
# ['* Persons who reported smoking ≥ 100 cigarettes during their lifetime and who , at the time of interview , reported smoking every day or some days .', 'Excludes 296 -LRB- 2005 -RRB- and 121 -LRB- 2013 -RRB- respondents whose smoking status was unknown .', '† Denotes significant linear trend during 2005 -- 2013 -LRB- p < 0.05 -RRB- , adjusted for sex , age , and race/ethnicity as applicable .', '§ Excludes 45 -LRB- 2005 -RRB- and 73 -LRB- 2013 -RRB- respondents of unknown race .', '** Among persons aged ≥ 25 years .', 'Excludes 339 -LRB- 2005 -RRB- and 155 -LRB- 2013 -RRB- persons whose educational level was unknown .', '2005 estimates are based on reported family income and 2004 poverty thresholds published by the U.S. Census Bureau , and 2013 estimates are based on reported family income and 2012 poverty thresholds published by the U.S. Census Bureau .', "Any disability/limitation was defined as a `` yes '' response pertaining to at least one of the disabilities/limitations listed -LRB- i.e. , vision , hearing , cognition , movement , activities of daily living , or instrumental activities of daily living -RRB- .", 'In 2013 , the American Community Survey disability questions were asked of a random half of families at the end of the family interview , with proxy reporting permitted for family members not present during the interview .', '*** Questions for pertaining to disabilities/limitations and sexual orientation were not included in the 2005 National Health Interview Survey .']
# About to parse
# Annotated
# []
# Done URL 10 out of 10
#
# Looking in document for values similar to 15.1
# https://www.cdc.gov/mmwr/preview/mmwrhtml/mm6444a2.htm
# https://www.cdc.gov/mmwr/preview/mmwrhtml/mm6444a2.htm
# 18 candidate matches
# ['* Persons who reported smoking ≥ 100 cigarettes during their lifetime and who , at the time of interview , reported smoking every day or some days .', 'Excludes 296 -LRB- 2005 -RRB- and 200 -LRB- 2014 -RRB- respondents whose smoking status was unknown .', '† Denotes significant linear trend during 2005 -- 2014 -LRB- p < 0.05 -RRB- , adjusted for sex , age , and race/ethnicity as applicable .', 'Although the table only presents data from the surveys in 2005 and 2014 , data from all the surveys for 2005 through 2014 were used in the trend analysis .', '§ Denotes significant difference in prevalence -LRB- p < 0.05 -RRB- between 2005 and 2014 .', '¶ Indicates an increase in the relative percentage change from 2005 to 2014 .', '** Excludes 30 -LRB- 2005 -RRB- and 62 -LRB- 2014 -RRB- respondents of non-Hispanic unknown race .', '§ § Among persons aged ≥ 25 years .', 'Excludes 339 -LRB- 2005 -RRB- and 162 -LRB- 2014 -RRB- persons whose education level was unknown .', '2005 estimates are based on reported family income and 2004 poverty thresholds published by the U.S. Census Bureau , and 2014 estimates are based on reported family income and 2013 poverty thresholds published by the U.S. Census Bureau .', 'Private insurance : Any comprehensive private insurance plan -LRB- including health maintenance and preferred provider organizations -RRB- , obtained through an employer , purchased directly , or purchased through local or community programs , and excludes plans that pay for only one type of service , such as accidents or dental care .', "A small number of persons -LRB- 132 respondents -RRB- were covered by both `` other public insurance '' and private plans and were included in both categories .", 'For 2014 , this group also included plans purchased through the Health Insurance Marketplace or a state-based exchange .', "A small number of persons -LRB- 132 respondents -RRB- were covered by both `` other public insurance '' and private plans and were included in both categories .", "Uninsured : Having no private health insurance , Medicare , Medicaid , Children 's Health Insurance Program , state-sponsored or other government-sponsored health plan , or military plan , or having only Indian Health Service coverage , or having only a private plan that paid for one type of service , such as accidents or dental care .", "Any disability/limitation was defined as a `` yes '' response pertaining to at least one of the disabilities/limitations listed -LRB- i.e. , vision , hearing , cognition , movement , activities of daily living , or instrumental activities of daily living -RRB- .", 'In 2014 , the American Community Survey questions were asked of a random half of the respondents from the 2014 Person File .', '¶ ¶ ¶ Questions pertaining to disabilities/limitations and sexual orientation were not included in the 2005 National Health Interview Survey .']
# About to parse
# Annotated
# []

# %% [markdown]
# ## Fact Checking
#
# ### Training
# Load Modules for fact checking, generate the features and train our classifier from our training data

# %%
from classifier.Classifier import Classifier
from classifier.LogisticRegressionClassifier import LogisticRegressionClassifier
from classifier.features.generate_features import FeatureGenerator, num, is_num
from distant_supervision.utterance_detection import f_threshold_match
from factchecking.question import Question
from tabular.filtering import load_collection

# %%
fg = FeatureGenerator()
Xs,ys = fg.generate_training(world)
# Out:
# Done: 0.0
# Search for ”Exxon Mobil" Market Value
# Query already executed
# Done: 6.25
# Search for "Unaccompanied children" claimed asylum
# Query already executed
# Done: 12.5
# Search for "Hamas" Founded
# Query already executed
# Done: 18.75
# Search for "United States" Average Temperature
# Query already executed
# Done: 25.0
# Search for "United States" Life expectancy
# Query already executed
# Done: 31.25
# Search for "United States" Number of abortions
# Query already executed
# Done: 37.5
# Search for "United States" Abortion Rate per 1,000 births
# Query already executed
# Done: 43.75
# Search for "United States Teenagers" Percentage Enrolled in education
# Query already executed
# Done: 50.0
# Search for "United States Teenagers" Enrolled in education
# Query already executed
# Done: 56.25
# Search for "America" bee colonies 2011
# Query already executed
# Done: 62.5
# Search for "United States" Financial Intermediary Funds 2016
# Query already executed
# Done: 68.75
# Search for "United States" Homocides by firearm
# Query already executed
# Done: 75.0
# Search for "United Kingdom" Educated at grammar schools 2016
# Query already executed
# Done: 81.25
# Search for "USA" Measles Vaccination Rate
# Query already executed
# Done: 87.5
# Search for "USA" Practicing doctors per 1000
# Query already executed
# Done: 93.75
# Search for "USA" Daily Smokers 2014
# Query already executed
# Registering + words in BOW
# Registering - words in BOW
# Registering columns
# Counting features
# Total positive: 25
# Total negative: 1501
# Looking for positive features
# 0
# Subsampling negative features
# 0

# %%
from sklearn.linear_model import LogisticRegression
class LogisticRegressionClassifier(Classifier):
    def train(self, Xs, ys):
        print("Training classifier 3")
        self.lr = LogisticRegression(penalty='l1', C=0.78)
        self.lr.fit(Xs, ys)
        print("Trained")

    def predict(self, q_features):
        ys = (self.lr.predict(q_features), self.lr.predict_proba(q_features))
        return ys


classifier = LogisticRegressionClassifier()
classifier.train(Xs,ys)
# Out:
# Training classifier 3
# Trained

# %% [markdown]
# ### Runtime
#
# Load the source data

# %%
tables = load_collection("herox")
print(tables.files)
# Out:
# LOADED:
# [{'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/1.tsv', 'id': 'hx-0'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/2.tsv', 'id': 'hx-1'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/3.tsv', 'id': 'hx-2'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/4.tsv', 'id': 'hx-3'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/5.tsv', 'id': 'hx-4'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/8.tsv', 'id': 'hx-5'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/9.tsv', 'id': 'hx-6'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/10.tsv', 'id': 'hx-7'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/11.tsv', 'id': 'hx-8'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/12.tsv', 'id': 'hx-9'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/13.tsv', 'id': 'hx-10'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/14.tsv', 'id': 'hx-11'}]
# register table herox/1.tsv
# register table herox/2.tsv
# register table herox/3.tsv
# register table herox/4.tsv
# register table herox/5.tsv
# register table herox/8.tsv
# register table herox/9.tsv
# register table herox/10.tsv
# register table herox/11.tsv
# register table herox/12.tsv
# register table herox/13.tsv
# register table herox/14.tsv
# {'herox/4.tsv', 'herox/2.tsv', 'herox/5.tsv', 'herox/11.tsv', 'herox/14.tsv', 'herox/13.tsv', 'herox/1.tsv', 'herox/9.tsv', 'herox/8.tsv', 'herox/3.tsv', 'herox/10.tsv', 'herox/12.tsv'}

# %% [markdown]
# Define the fact checking function

# %%
def fact_check(q):
    question = Question(text=q, type="NUM")
    question.parse()
    tuples,q_features = fg.generate_test(tables,question)
    q_match = False
    
    if len(tuples)>0:
        q_predicted = classifier.predict(q_features)

        for i in range(len(tuples)):
            tuple = tuples[i]
            
            skip = False
            if 'date' in tuple[1].keys() and len(question.dates):
                for date in question.dates:
                    dstrs = set()
                    for d in question.dates:
                        dstrs.add(str(d))
                    if not len(set(tuple[1]['date']).intersection(dstrs)):
                        skip = True
                        
            if skip:
                continue
    

            if is_num(tuple[1]['value']):
                prediction = q_predicted[0][i]
                features = q_features[i]

                
             
                if prediction == 1:
                    print(str(tuple) + "\t\t" + ("Possible Match" if prediction else "No match"))
                    for number in question.numbers:
                        value = num(tuple[1]['value'])

                        if value is None:
                            continue

                        if f_threshold_match(number, value, 0.05):
                            print(str(tuple) + "\t\t" + "Threshold Match to 5%")
                            q_match = True

                    for number in question.dates:
                        value = num(tuple[1]['value'])
                        if number == value:
                            print(str(tuple) + "\t\t" + "Exact Match")
                            q_match = True
        print(question.text)
        print(q_match)

    else:
        print(question.text)
        print("No supporting information can be found in the knowledge base")
    print("\n\n")

# %% [markdown]
# # Fact checking

# %%
fact_check("23,000 sheep Germany 2014")
# Out:
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Germany', 'value': '80.84390244', 'date': ['2014']})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'entity': 'Germany', 'value': '4400', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'entity': '
 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.101261', 'date': ['1902', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.101261', 'date': ['1902', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.9506507', 'date': ['1903', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.9506507', 'date': ['1903', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.9506507', 'date': ['1903', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.9506507', 'date': ['1903', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.157038', 'date': ['1903', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.157038', 'date': ['1903', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.157038', 'date': ['1903', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.157038', 'date': ['1903', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.117554925', 'date': ['1903', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.117554925', 'date': ['1903', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.117554925', 'date': ['1903', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.117554925', 'date': ['1903', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.013507', 'date': ['1903', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.013507', 'date': ['1903', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.013507', 'date': ['1903', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.013507', 'date': ['1903', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.39642', 'date': ['1903', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.39642', 'date': ['1903', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.39642', 'date': ['1903', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.39642', 'date': ['1903', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.831163', 'date': ['1903', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.831163', 'date': ['1903', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.831163', 'date': ['1903', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.831163', 'date': ['1903', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.743898', 'date': ['1903', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.743898', 'date': ['1903', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.743898', 'date': ['1903', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.743898', 'date': ['1903', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.135069', 'date': ['1903', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.135069', 'date': ['1903', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.135069', 'date': ['1903', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.135069', 'date': ['1903', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '13.529861', 'date': ['1903', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '13.529861', 'date': ['1903', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '13.529861', 'date': ['1903', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '13.529861', 'date': ['1903', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4442024', 'date': ['1903', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4442024', 'date': ['1903', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4442024', 'date': ['1903', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4442024', 'date': ['1903', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.58384866', 'date': ['1903', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.58384866', 'date': ['1903', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.58384866', 'date': ['1903', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.58384866', 'date': ['1903', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.6340113', 'date': ['1903', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.6340113', 'date': ['1903', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.6340113', 'date': ['1903', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.6340113', 'date': ['1903', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-7.3816924', 'date': ['1904', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-7.3816924', 'date': ['1904', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-7.3816924', 'date': ['1904', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-7.3816924', 'date': ['1904', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.390297', 'date': ['1904', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.390297', 'date': ['1904', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.390297', 'date': ['1904', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.390297', 'date': ['1904', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.79961354', 'date': ['1904', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.79961354', 'date': ['1904', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.79961354', 'date': ['1904', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.79961354', 'date': ['1904', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.1888933', 'date': ['1904', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.1888933', 'date': ['1904', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.1888933', 'date': ['1904', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.1888933', 'date': ['1904', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.800284', 'date': ['1904', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.800284', 'date': ['1904', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.800284', 'date': ['1904', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.800284', 'date': ['1904', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.434887', 'date': ['1904', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.434887', 'date': ['1904', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.434887', 'date': ['1904', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.434887', 'date': ['1904', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.859074', 'date': ['1904', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.859074', 'date': ['1904', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.859074', 'date': ['1904', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.859074', 'date': ['1904', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '17.585863', 'date': ['1904', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '17.585863', 'date': ['1904', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '17.585863', 'date': ['1904', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '17.585863', 'date': ['1904', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.134845', 'date': ['1904', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.134845', 'date': ['1904', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.134845', 'date': ['1904', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.134845', 'date': ['1904', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.6272783', 'date': ['1904', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.6272783', 'date': ['1904', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.6272783', 'date': ['1904', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.6272783', 'date': ['1904', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.9991253', 'date': ['1904', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.9991253', 'date': ['1904', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.9991253', 'date': ['1904', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.9991253', 'date': ['1904', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.260049', 'date': ['1904', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.260049', 'date': ['1904', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.260049', 'date': ['1904', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.260049', 'date': ['1904', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.370586', 'date': ['1905', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.370586', 'date': ['1905', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.370586', 'date': ['1905', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.370586', 'date': ['1905', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.7490845', 'date': ['1905', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.7490845', 'date': ['1905', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.7490845', 'date': ['1905', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.7490845', 'date': ['1905', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '2.1014647', 'date': ['1905', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '2.1014647', 'date': ['1905', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '2.1014647', 'date': ['1905', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '2.1014647', 'date': ['1905', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.0607', 'date': ['1905', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.0607', 'date': ['1905', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.0607', 'date': ['1905', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.0607', 'date': ['1905', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.647071', 'date': ['1905', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.647071', 'date': ['1905', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.647071', 'date': ['1905', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.647071', 'date': ['1905', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.717594', 'date': ['1905', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.717594', 'date': ['1905', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.717594', 'date': ['1905', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.717594', 'date': ['1905', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.822111', 'date': ['1905', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.822111', 'date': ['1905', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.822111', 'date': ['1905', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.822111', 'date': ['1905', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.583889', 'date': ['1905', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.583889', 'date': ['1905', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.583889', 'date': ['1905', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.583889', 'date': ['1905', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.350935', 'date': ['1905', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.350935', 'date': ['1905', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.350935', 'date': ['1905', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.350935', 'date': ['1905', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.6374903', 'date': ['1905', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.6374903', 'date': ['1905', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.6374903', 'date': ['1905', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.6374903', 'date': ['1905', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '1.5394223', 'date': ['1905', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '1.5394223', 'date': ['1905', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '1.5394223', 'date': ['1905', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '1.5394223', 'date': ['1905', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.145606', 'date': ['1905', 'December'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.5096626', 'date': ['1906', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.5096626', 'date': ['1906', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.5096626', 'date': ['1906', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-6.5096626', 'date': ['1906', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.6716843', 'date': ['1906', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.6716843', 'date': ['1906', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.6716843', 'date': ['1906', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.6716843', 'date': ['1906', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-1.4720911', 'date': ['1906', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-1.4720911', 'date': ['1906', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-1.4720911', 'date': ['1906', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-1.4720911', 'date': ['1906', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.308421', 'date': ['1906', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.308421', 'date': ['1906', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.308421', 'date': ['1906', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '6.308421', 'date': ['1906', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.539341', 'date': ['1906', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.539341', 'date': ['1906', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.539341', 'date': ['1906', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '11.539341', 'date': ['1906', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.339931', 'date': ['1906', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.339931', 'date': ['1906', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.339931', 'date': ['1906', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '16.339931', 'date': ['1906', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '19.006163', 'date': ['1906', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '19.006163', 'date': ['1906', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '19.006163', 'date': ['1906', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '19.006163', 'date': ['1906', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.44105', 'date': ['1906', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.44105', 'date': ['1906', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.44105', 'date': ['1906', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.44105', 'date': ['1906', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.000834', 'date': ['1906', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.000834', 'date': ['1906', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.000834', 'date': ['1906', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.000834', 'date': ['1906', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4794755', 'date': ['1906', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4794755', 'date': ['1906', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4794755', 'date': ['1906', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.4794755', 'date': ['1906', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.013547599', 'date': ['1906', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.013547599', 'date': ['1906', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.013547599', 'date': ['1906', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.013547599', 'date': ['1906', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.2010374', 'date': ['1906', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.2010374', 'date': ['1906', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.2010374', 'date': ['1906', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.2010374', 'date': ['1906', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.284276', 'date': ['1907', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.284276', 'date': ['1907', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.284276', 'date': ['1907', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.284276', 'date': ['1907', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-5.1473556', 'date': ['1907', 'February'], 'entity': 'USA'})		Threshold Match to 5%
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.96702605', 'date': ['1907', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.96702605', 'date': ['1907', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.96702605', 'date': ['1907', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.96702605', 'date': ['1907', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '4.4491253', 'date': ['1907', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '4.4491253', 'date': ['1907', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '4.4491253', 'date': ['1907', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '4.4491253', 'date': ['1907', 'April'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '10.292026', 'date': ['1907', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '10.292026', 'date': ['1907', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '10.292026', 'date': ['1907', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '10.292026', 'date': ['1907', 'May'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.531795', 'date': ['1907', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.531795', 'date': ['1907', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.531795', 'date': ['1907', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '15.531795', 'date': ['1907', 'June'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.964462', 'date': ['1907', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.964462', 'date': ['1907', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.964462', 'date': ['1907', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.964462', 'date': ['1907', 'July'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.049227', 'date': ['1907', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.049227', 'date': ['1907', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.049227', 'date': ['1907', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '18.049227', 'date': ['1907', 'August'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.102034', 'date': ['1907', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.102034', 'date': ['1907', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.102034', 'date': ['1907', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '14.102034', 'date': ['1907', 'September'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.295667', 'date': ['1907', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.295667', 'date': ['1907', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.295667', 'date': ['1907', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '7.295667', 'date': ['1907', 'October'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.005919447', 'date': ['1907', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.005919447', 'date': ['1907', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.005919447', 'date': ['1907', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-0.005919447', 'date': ['1907', 'November'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.295484', 'date': ['1907', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.295484', 'date': ['1907', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.295484', 'date': ['1907', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-3.295484', 'date': ['1907', 'December'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.748088', 'date': ['1908', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.748088', 'date': ['1908', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.748088', 'date': ['1908', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.748088', 'date': ['1908', 'January'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.050997', 'date': ['1908', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.050997', 'date': ['1908', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.050997', 'date': ['1908', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '-4.050997', 'date': ['1908', 'February'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.56108624', 'date': ['1908', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.56108624', 'date': ['1908', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.56108624', 'date': ['1908', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '0.56108624', 'date': ['1908', 'March'], 'entity': 'USA'})		Possible Match
# ('herox/4.tsv', {'relation': 'Temperature (C)', 'value': '5.966497', 'date': ['1908', 'April'], 'entity': 'USA'})		Possible Match
# ...
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '73.81858977', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '73.81858977', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '73.81858977', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.03896568', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.03896568', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.03896568', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.03896568', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.8259382', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.8259382', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.8259382', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.8259382', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '73.91387068', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '73.91387068', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '73.91387068', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '73.91387068', 'date': ['2010']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.04087527', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.04087527', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.04087527', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.04087527', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.26333547', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.26333547', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.26333547', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.26333547', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.91060374', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.91060374', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.91060374', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '78.91060374', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.14126826', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.14126826', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.14126826', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.14126826', 'date': ['2011']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.26486374', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.26486374', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.26486374', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.26486374', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.48749666', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.48749666', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.48749666', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.48749666', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.02297105', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.02297105', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.02297105', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.02297105', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.37018061', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.37018061', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.37018061', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.37018061', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.49012862', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.49012862', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.49012862', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.49012862', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.71364011', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.71364011', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.71364011', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.71364011', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.13406468', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.13406468', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.13406468', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.13406468', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.5998853', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.5998853', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.5998853', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.5998853', 'date': ['2013']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.71736292', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.71736292', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.71736292', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean (excluding high income)', 'value': '74.71736292', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.94196452', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.94196452', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.94196452', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & Caribbean', 'value': '74.94196452', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.24410183', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.24410183', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.24410183', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'North America', 'value': '79.24410183', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.83097562', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.83097562', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.83097562', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'value': '74.83097562', 'date': ['2014']})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# -5 degree celsius was the temperature in USA
# True
